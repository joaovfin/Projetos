# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovfin/Projetos/blob/main/02_Market_correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Market Correlation

# %%
# !pip install yfinance --upgrade --no-cache-dir
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import yfinance as yf
yf.pdr_override()

import seaborn as sns

# %%
tickers = ["^BVSP", "USDBRL=X"]
carteira=web.get_data_yahoo(tickers,start="2018-01-01")["Close"]
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
carteira
# Out:
#             USDBRL=X          ^BVSP
# Date
# 2018-01-01    3.3076            NaN
# 2018-01-02    3.3110   77891.000000
# 2018-01-03    3.2578   77995.000000
# 2018-01-04    3.2355   78647.000000
# 2018-01-05    3.2331   79071.000000
# ...              ...            ...
# 2021-02-04    5.3520  119261.000000
# 2021-02-05    5.4257  119925.000000
# 2021-02-08    5.3692  119516.000000
# 2021-02-09    5.3643  119429.000000
# 2021-02-10    5.3646  118640.976562
#
# [813 rows x 2 columns]

# %%
carteira=carteira.dropna()
carteira
# Out:
#             USDBRL=X          ^BVSP
# Date
# 2018-01-02    3.3110   77891.000000
# 2018-01-03    3.2578   77995.000000
# 2018-01-04    3.2355   78647.000000
# 2018-01-05    3.2331   79071.000000
# 2018-01-08    3.2266   79379.000000
# ...              ...            ...
# 2021-02-04    5.3520  119261.000000
# 2021-02-05    5.4257  119925.000000
# 2021-02-08    5.3692  119516.000000
# 2021-02-09    5.3643  119429.000000
# 2021-02-10    5.3646  118640.976562
#
# [744 rows x 2 columns]

# %%
carteira.columns=["DOLAR","IBOV"]

# %%
sns.set()
carteira.plot(subplots=True, figsize=(20,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f94c4676dd8>,
# ...
#       dtype=object)

# %%
sns.heatmap(carteira.corr(),annot=True)

# %%
carteira["DOLAR"].rolling(252).corr(carteira["IBOV"]).plot(figsize=(20,8))
