# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovfin/Projetos/blob/main/03_Portfolio_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance --upgrade --no-cache-dir
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import yfinance as yf
yf.pdr_override()

import seaborn as sns

# %%
tickers=["ITSA4.SA","WEGE3.SA","TIET11.SA","VVAR3.SA"]

carteira=web.get_data_yahoo(tickers,period="3y")["Adj Close"]

bova=web.get_data_yahoo("BOVA11.SA",period="3y")["Adj Close"]
# Out:
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  1 of 1 completed

# %%
carteira

# %%
bova
# Out:
# Date
# 2018-02-15     81.400002
# 2018-02-16     81.559998
# 2018-02-19     81.860001
# 2018-02-20     82.940002
# 2018-02-21     83.040001
#                  ...
# 2021-02-04    115.010002
# 2021-02-05    115.820000
# 2021-02-08    114.860001
# 2021-02-09    115.180000
# 2021-02-10    113.760002
# Name: Adj Close, Length: 737, dtype: float64

# %%
carteira=carteira.dropna()
ibov=ibov.dropna()

# %%
sns.set()
carteira.plot(figsize=(20,8))

# %%
carteira_norm=(carteira/carteira.iloc[0])*1000
carteira_norm

# %%
sns.set()
carteira_norm.plot(figsize=(20,8))

# %%
carteira_norm["Saldo"]=carteira_norm.sum(axis=1)
carteira_norm
# Out:
#                ITSA4.SA    TIET11.SA     VVAR3.SA     WEGE3.SA        Saldo
# Date
# 2018-02-15  1000.000000  1000.000000  1000.000000  1000.000000  4000.000000
# 2018-02-16  1023.682274   985.678016   984.848516   976.932827  3971.141632
# 2018-02-19  1021.390413   998.314802   977.272653   981.204775  3978.182643
# 2018-02-20  1062.643428  1018.533880   960.858576   980.350231  4022.386114
# 2018-02-21  1080.977737  1004.212225   969.696911   975.651231  4030.538105
# ...                 ...          ...          ...          ...          ...
# 2021-02-04  1091.900504  1932.395695  1896.741074  4951.910533  9872.947805
# 2021-02-05  1086.854829  1950.843369  1904.328091  4944.966010  9886.992299
# 2021-02-08  1069.699268  1950.843369  1924.559977  4947.859672  9892.962285
# 2021-02-09  1078.781539  1942.772539  1887.889654  4969.271621  9878.715353
# 2021-02-10  1066.671748  1890.888319  1847.425762  4902.721373  9707.707203
#
# [737 rows x 5 columns]

# %%
bova_norm=(bova/bova.iloc[0])*4000
bova_norm
# Out:
# Date
# 2018-02-15    4000.000000
# 2018-02-16    4007.862213
# 2018-02-19    4022.604377
# 2018-02-20    4075.675719
# 2018-02-21    4080.589649
#                  ...
# 2021-02-04    5651.597051
# 2021-02-05    5691.400370
# 2021-02-08    5644.225968
# 2021-02-09    5659.950769
# 2021-02-10    5590.171990
# Name: Adj Close, Length: 737, dtype: float64

# %%
sns.set()
carteira_norm["Saldo"].plot(figsize=(20,8), label ="Minha Carteira")
bova_norm.plot(label="BOVA11")
