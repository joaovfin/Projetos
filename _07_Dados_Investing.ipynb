# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovfin/Projetos/blob/main/_07_Dados_Investing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalando as bibliotecas e carregando-as
# !pip install investpy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib
import investpy as inv

# %%
#Lista de criptomoedas
criptos=inv.get_cryptos_list()
criptos
# Out:
# ['Bitcoin',
#  'Ethereum',
#  'Binance Coin',
#  'Tether',
#  'Cardano',
#  'Polkadot',
#  'XRP',
#  'Uniswap',
#  'Litecoin',
#  'Chainlink',
#  'THETA',
#  'USD Coin',
#  'Bitcoin Cash',
#  'Stellar',
#  'Terra',
#  'Wrapped Bitcoin',
#  'Dogecoin',
#  'VeChain',
#  'Crypto.com Coin',
#  'Filecoin',
#  'Aave',
#  'TRON',
#  'IOTA',
#  'Cosmos',
#  'Solana',
#  'EOS',
#  'Avalanche',
#  'Monero',
#  'Bitcoin SV',
#  'Kusama',
#  'FTX Token',
#  'Tezos',
#  'NEM',
#  'BitTorrent',
#  'Algorand',
#  'Neo',
#  'Chiliz',
#  'Dai',
#  'Huobi Token',
#  'Hedera Hashgraph',
#  'Elrond',
#  'SushiSwap',
#  'Synthetix',
#  'Dash',
#  'Theta Fuel',
#  'UNUS SED LEO',
#  'The Graph',
#  'Decred',
#  'Maker',
#  'Zilliqa',
#  'Compound',
#  'Polygon',
#  'NEAR Protocol',
#  'Enjin Coin',
#  'Ravencoin',
#  'Basic Attention Token',
#  'Pundi X',
#  'Zcash',
#  'PancakeSwap',
#  'Harmony',
#  'Decentraland',
#  'Nexo',
#  'UMA',
#  'Ethereum Classic',
#  'Bancor',
#  'SwissBorg',
#  'THORChain',
# ...

# %%
#Quantidade de criptomoedas
len(criptos)
# Out:
# 1037

# %%
#Listando os fundos de investimentos do Brasil. Podemos pesquisar por outros paises.
fundos=inv.get_funds_list(country='brazil')
fundos
# Out:
# ['Fundo De Investimento Multimercado Bordeaux Iv Crédito Privado Investimento No Exterior',
#  'Cshg Warrior V Fundo De Investimento Multimercado - Crédito Privado Investimento No Exterior',
#  'A3 Viking Fi Em Quotas De Fi Multimercado Crédito Privado Investimento No Exterior',
#  'Bb Espelho Multimercado Lp J. Safra Absoluto 30 Private Fic Fi',
#  'Ctm Hedge Fundo De Investimento Multimercado - Longo Prazo',
#  'Vif - Fundo De Investimento Em Cotas De Fundos De Investimento Multimercado',
#  'Fundo De Investimento Multimercado Bordeaux Iii Crédito Privado Investimento No Exterior',
#  'Bb Top Tatico Fundo De Investimento Multimercado',
#  'Epm Fundo De Investimento Multimercado Crédito Privado Investimento No Exterior',
#  'Western Asset Multitrading H Multimercado Fundo De Investimento',
#  'Concordia Phoenix Fundo De Investimento Multimercado Crédito Privado',
#  'Fundo De Investimento Multimercado Irmb Crédito Privado - Investimento No Exterior',
# ...

# %%
#Quantidade de fundos no Brasil
len(fundos)
# Out:
# 5200

# %%
#Fazendo uma pesquisa de um fundo 
pesquisa=inv.search_funds(by='name', value='alaska')
pesquisa
# Out:
#           country  ... underlying
# 0          brazil  ...        NaN
# 1          brazil  ...        NaN
# 2          brazil  ...        NaN
# 3          brazil  ...        NaN
# 4          brazil  ...        NaN
# 5          brazil  ...        NaN
# 6          brazil  ...        NaN
# 7          brazil  ...        NaN
# 8          brazil  ...        NaN
# 9          brazil  ...        NaN
# 10  united states  ...        NaN
# 11  united states  ...        NaN
# 12  united states  ...        NaN
# 13  united states  ...        NaN
#
# [14 rows x 8 columns]

# %%
#Extraindo o nome do fundo desejado
pesquisa['name'][4]
# Out:
# 'Alaska Black Master Fundo De Investimento Em Ações - Bdr Nível I'

# %%
#Buscando informações do fundo
fundo='Alaska Black Master Fundo De Investimento Em Ações - Bdr Nível I'
fund_information = inv.get_fund_information(fundo,country='brazil')
fund_information

#Em formato JSON
#fund_information = inv.get_fund_information(fundo,country='brazil',as_json=True)
#fund_information
# Out:
#                                            Fund Name  ... Category
# 0  alaska black master fundo de investimento em a...  ...      NaN
#
# [1 rows x 16 columns]

# %%
#Histórico de cotas do fundo em R$
alaska=inv.get_fund_historical_data(fundo,country='brazil',from_date=('01/01/2017'), to_date=('15/04/2021'))
alaska
# Out:
#              Open   High    Low  Close Currency
# Date
# 2017-01-02  2.250  2.250  2.250  2.250      BRL
# 2017-01-03  2.319  2.319  2.319  2.319      BRL
# 2017-01-04  2.238  2.238  2.238  2.238      BRL
# 2017-01-05  2.235  2.235  2.235  2.235      BRL
# 2017-01-06  2.213  2.213  2.213  2.213      BRL
# ...           ...    ...    ...    ...      ...
# 2021-04-07  4.267  4.267  4.267  4.267      BRL
# 2021-04-08  4.336  4.336  4.336  4.336      BRL
# 2021-04-09  4.221  4.221  4.221  4.221      BRL
# 2021-04-12  4.264  4.264  4.264  4.264      BRL
# 2021-04-13  4.343  4.343  4.343  4.343      BRL
#
# [1062 rows x 5 columns]

# %%
alaska.plot(figsize=(20,8))

# %%
#Pesquisando a lista de ações
inv.get_stocks_list(country='brazil')
# Out:
# ['ABCB4',
#  'AGRO3',
#  'RAIL3',
#  'ALPA3',
#  'ALPA4',
#  'ALSO3',
#  'AMAR3',
#  'ABEV3',
#  'ADHM3',
#  'ARZZ3',
#  'BBAS3',
#  'BBDC3',
#  'BBDC4',
#  'BBRK3',
#  'BEEF3',
#  'BPHA3',
#  'BPAN4',
#  'BRAP3',
#  'BRAP4',
#  'BRFS3',
#  'APER3',
#  'BRKM3',
#  'BRKM5',
#  'BRML3',
#  'BRPR3',
#  'BRSR6',
#  'OIBR3',
#  'OIBR4',
#  'BTOW3',
#  'B3SA3',
#  'CAMB4',
#  'CARD3',
#  'CCPR3',
#  'CCRO3',
#  'CEDO4',
#  'CEED3',
#  'CESP6',
#  'CGAS5',
#  'CGRA4',
#  'CIEL3',
#  'CMIG3',
#  'CMIG4',
#  'COCE5',
#  'CPFE3',
#  'CPLE3',
#  'CPLE6',
#  'CRDE3',
#  'CSAN3',
#  'CSMG3',
#  'CSNA3',
#  'LIQO3',
#  'CTNM4',
#  'CYRE3',
#  'DASA3',
#  'DIRR3',
#  'DTEX3',
#  'ECOR3',
#  'EEEL3',
#  'ELEK4',
#  'ELET3',
#  'ELET6',
#  'EMBR3',
#  'ENBR3',
#  'ENGI4',
#  'EQTL3',
#  'YDUQ3',
#  'ETER3',
#  'EUCA4',
#  'EVEN3',
#  'EZTC3',
#  'FESA4',
#  'FHER3',
#  'TASA4',
#  'FLRY3',
#  'FRIO3',
#  'TIET3',
#  'TIET4',
#  'GFSA3',
#  'GGBR3',
#  'GGBR4',
#  'GOAU3',
#  'GOAU4',
#  'GOLL4',
# ...

# %%
#Carregando dados do ITUB4 com intervalo mensal
itub4=inv.get_stock_historical_data('ITUB4',country='brazil',from_date=('01/01/2020'),to_date='01/01/2021',interval='Weekly')
itub4
# Out:
#              Open   High    Low  Close     Volume Currency
# Date
# 2020-01-05  35.68  35.71  32.80  32.88  142221904      BRL
# 2020-01-12  33.28  33.64  32.69  33.20  122971904      BRL
# 2020-01-19  33.07  33.26  31.74  32.54  110477504      BRL
# 2020-01-26  32.06  32.39  30.92  31.19  118893504      BRL
# 2020-02-02  31.37  32.47  31.17  32.05  131713000      BRL
# 2020-02-09  32.07  33.73  32.01  32.14  259595808      BRL
# 2020-02-16  32.31  32.72  31.34  32.02  143469104      BRL
# 2020-02-23  30.47  31.67  29.95  31.35  152307200      BRL
# 2020-03-01  31.27  31.65  28.74  29.28  189031904      BRL
# 2020-03-08  27.44  29.11  21.96  25.69  287090400      BRL
# 2020-03-15  23.03  26.18  20.71  21.61  362485888      BRL
# 2020-03-22  21.82  24.33  19.60  22.51  240772800      BRL
# 2020-03-29  22.65  23.91  19.63  20.26  190667200      BRL
# 2020-04-05  21.71  24.23  21.47  23.05  155018208      BRL
# 2020-04-12  23.00  24.67  22.18  22.77  145604192      BRL
# ...

# %%
itub4['Close'].plot(figsize=(20,8))
